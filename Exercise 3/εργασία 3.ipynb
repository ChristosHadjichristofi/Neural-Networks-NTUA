# %%
NUMBER_OF_IMAGES = 6000 # default = 6000


#PREPROCESSING
MIN_CAPTION_LEN = 4
MAX_CAPTION_LEN = 50
MAX_LENGTH = 50 # default = 50
VOCABULARY_SIZE = 10000 # default = 5000


#ENCODER
CNN_USED = 'InceptionV3'
# CNN_USED = 'ResNet152V2'


#EMBEDDINGS
PRETRAINED_EMBEDDINGS = False
EMBEDDING_DIM = 256 # for False: default 256
# EMBEDDING_DIM = 300 # for True: 50, 100, 200 or 300


#REGULARIZATION
DROPOUT_AFTER_FC1 = True
DROPOUT_AFTER_FC2 = True
DROPOUT_VALUE_1 = 0.5
DROPOUT_VALUE_2 = 0.5


#DECODER
# DECODER_LAYER = 'GRU'
DECODER_LAYER = 'LSTM'
UNITS = 512 # default =  512


#SENTENCE GENERATOR
SENTENCE_GENERATOR_METHOD = 'CATEGORICAL'
# SENTENCE_GENERATOR_METHOD = 'BEAM_SEARCH'
BEAM_WIDTH = 5


#TRAINING
EPOCHS = 60

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.63.0)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# your model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image
from tqdm import tqdm
import csv
import nltk
from nltk.translate.bleu_score import SmoothingFunction
from keras.preprocessing import sequence
import gensim.downloader
from tensorflow.keras.layers import Embedding
import keras.initializers

# %%
# Download caption annotation files
annotation_folder = '/train_captions/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  train_captions_file = tf.keras.utils.get_file('train_captions.csv',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='https://www.dropbox.com/s/qqrsitwecf7fjd3/train_captions.csv?dl=1',
                                           extract=False)
  annotation_file = os.path.dirname(train_captions_file)+'/train_captions.csv'
# Out:
# Downloading data from https://www.dropbox.com/s/qqrsitwecf7fjd3/train_captions.csv?dl=1
# 12492800/12484775 [==============================] - 1s 0us/step
# 12500992/12484775 [==============================] - 1s 0us/step

# %%
# Download image files
image_folder = '/image_dir/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('flickr30k-images-ecemod.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='https://www.dropbox.com/s/efqe8131slq1zah/flickr30k-images-ecemod.zip?dl=1',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from https://www.dropbox.com/s/efqe8131slq1zah/flickr30k-images-ecemod.zip?dl=1
# 4376387584/4376381805 [==============================] - 268s 0us/step
# 4376395776/4376381805 [==============================] - 268s 0us/step

# %% [markdown]
# ## Load images and captions and filter based on caption length

# %%
with open(annotation_file, 'r') as f:
  csvreader = csv.reader(f)
  annotations = []
  for row in csvreader:
    annotations.append(row)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations:
  val_joined = ','.join(val)
  val_splitted = val_joined.split('|')
  caption = f"<start> {val_splitted[2]} <end>"
  image_path = PATH + val_splitted[0]
  image_path_to_caption[image_path].append(caption)

# %%
print(image_path_to_caption['/content/image_dir/_998409888.jpg'])
# Out:
# ['<start>  A young boy jumps in the air on a pathway under construction in the hills . <end>', '<start>  The little kids is jumping off a ledge and into the dirt below it . <end>', '<start>  A boy is jumping over a large hole in the ground . <end>', '<start>  A wmoan is jumping off land and into a ditch . <end>', '<start>  A person jumping into a hole . <end>']

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first NUMBER_OF_IMAGES image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 5*NUMBER_OF_IMAGES examples.
train_image_paths = image_paths[:NUMBER_OF_IMAGES] 
print(len(train_image_paths))
# Out:
# 6000

# %%
train_captions = []
img_name_vector = []
caption_lengths = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  for caption in caption_list:
    temp_caption_len = len(caption.split(" ")) - 3
    if (temp_caption_len < MIN_CAPTION_LEN) or (temp_caption_len > MAX_CAPTION_LEN):
      caption_list.remove(caption)
    else:
      caption_lengths.append(temp_caption_len)

  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
print("Captions after filtering based on length:",len(caption_lengths))

n, bins, patches = plt.hist(caption_lengths, bins = (MAX_CAPTION_LEN - MIN_CAPTION_LEN + 1))
plt.xlabel('Caption length')
plt.ylabel('Number of captions')
plt.title('Histogram of caption lengths')
plt.grid(True)
plt.show()
# Out:
# Captions after filtering based on length: 29965

# %%
print(train_captions[2])
Image.open(img_name_vector[2])
# Out:
# <start>  A man in red tights balances on a beam with his legs in the air . <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x357 at 0x7F05DA886090>

# %% [markdown]
# ## Load image using InceptionV3

# %%
def load_image_InceptionV3(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ## Load image using ResNet152V2

# %%
def load_image_ResNet152v2(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(224, 224)(img)
    img = tf.keras.applications.resnet_v2.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ## Preprocess using CNN

# %%
if (CNN_USED == 'InceptionV3'):
  image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                  weights='imagenet')
else:
  image_model = tf.keras.applications.resnet_v2.ResNet152V2(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# 87924736/87910968 [==============================] - 2s 0us/step

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
if (CNN_USED == 'InceptionV3'):
  image_dataset = image_dataset.map(load_image_InceptionV3, num_parallel_calls=tf.data.AUTOTUNE).batch(16)
else:
  image_dataset = image_dataset.map(load_image_ResNet152v2, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 375/375 [02:22<00:00,  2.64it/s]

# %% [markdown]
# ## Preprocess and tokenize the captions

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)

# We will override the default standardization of TextVectorization to preserve
# "<>" characters, so we preserve the tokens for the <start> and <end>.
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max word count for a caption.
max_length = MAX_LENGTH 
# Use the top VOCABULARY_SIZE words for a vocabulary.
vocabulary_size = VOCABULARY_SIZE 
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# %%
# Create the tokenized vectors
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %% [markdown]
# ## Split the data into training and testing

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (23981, 23981, 5998, 5998)

# %% [markdown]
# ## Create a tf.data dataset for training

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# Shape of the vector extracted from ResNet152V2 is (49, 2048)
# These two variables represent that vector shape
features_shape = 2048
if (CNN_USED == 'InceptionV3'):
  attention_features_shape = 64
else:
  attention_features_shape = 49

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int64]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# ## Pre-trained Embeddings

# %%
if(PRETRAINED_EMBEDDINGS):
  # !wget http://nlp.stanford.edu/data/glove.6B.zip
  # !unzip -q glove.6B.zip

# %%
if(PRETRAINED_EMBEDDINGS):
  path_to_glove_file = os.path.join(
      os.path.expanduser("~"), "/content/glove.6B." + str(EMBEDDING_DIM) + "d.txt"
  )

  embeddings_index = {}
  with open(path_to_glove_file) as f:
      for line in f:
          word, coefs = line.split(maxsplit=1)
          coefs = np.fromstring(coefs, "f", sep=" ")
          embeddings_index[word] = coefs

  print("Found %s word vectors." % len(embeddings_index))

# %%
if(PRETRAINED_EMBEDDINGS):
  num_tokens = VOCABULARY_SIZE + 2
  hits = 0
  misses = 0

  # Prepare embedding matrix
  embedding_matrix = np.zeros((num_tokens, EMBEDDING_DIM))
  words = tokenizer.get_vocabulary()
  for i,word in enumerate(words):
      embedding_vector = embeddings_index.get(word)
      if embedding_vector is not None:
          # Words not found in embedding index will be all-zeros.
          # This includes the representation for "padding" and "OOV"
          embedding_matrix[i] = embedding_vector
          hits += 1
      else:
          misses += 1
  print("Converted %d words (%d misses)" % (hits, misses))

# %% [markdown]
# ## Model

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, EMBEDDING_DIM)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, EMBEDDING_DIM):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, EMBEDDING_DIM)
        self.fc = tf.keras.layers.Dense(EMBEDDING_DIM)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, EMBEDDING_DIM, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    if(not PRETRAINED_EMBEDDINGS):
      self.embedding = tf.keras.layers.Embedding(vocab_size, EMBEDDING_DIM)
    else:
      self.embedding = Embedding(
                        num_tokens,
                        EMBEDDING_DIM,
                        embeddings_initializer=keras.initializers.Constant(embedding_matrix),
                        trainable=False,
                    )

    if(DECODER_LAYER == 'GRU'): 
      self.decoder_layer = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    else:
      self.decoder_layer = tf.keras.layers.LSTM(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')

    
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.dropout1 = tf.keras.layers.Dropout(DROPOUT_VALUE_1)
    self.dropout2 = tf.keras.layers.Dropout(DROPOUT_VALUE_2)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, EMBEDDING_DIM)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, EMBEDDING_DIM + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU/LSTM
    if(DECODER_LAYER == 'GRU'): 
      output, state = self.decoder_layer(x)
    else:
      output, state, carry_state = self.decoder_layer(x)
      # final_memory_state, final_carry_state

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    if (DROPOUT_AFTER_FC1):
      x = self.dropout1(x)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    if (DROPOUT_AFTER_FC2):
      x = self.dropout2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(EMBEDDING_DIM)
decoder = RNN_Decoder(EMBEDDING_DIM, units, tokenizer.vocabulary_size())

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Training

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([word_to_index('<start>')] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 2.8299
# Epoch 1 Batch 100 Loss 1.6262
# Epoch 1 Batch 200 Loss 1.4464
# Epoch 1 Batch 300 Loss 1.1519
# Epoch 1 Loss 1.432618
# Time taken for 1 epoch 334.78 sec
#
# Epoch 2 Batch 0 Loss 1.3404
# Epoch 2 Batch 100 Loss 1.1545
# Epoch 2 Batch 200 Loss 0.9774
# Epoch 2 Batch 300 Loss 1.1392
# Epoch 2 Loss 1.131308
# Time taken for 1 epoch 199.08 sec
#
# Epoch 3 Batch 0 Loss 1.1534
# Epoch 3 Batch 100 Loss 1.1752
# Epoch 3 Batch 200 Loss 0.9053
# Epoch 3 Batch 300 Loss 0.9543
# Epoch 3 Loss 1.013309
# Time taken for 1 epoch 198.09 sec
#
# Epoch 4 Batch 0 Loss 1.0224
# Epoch 4 Batch 100 Loss 0.8495
# Epoch 4 Batch 200 Loss 0.9109
# Epoch 4 Batch 300 Loss 0.9607
# Epoch 4 Loss 0.938418
# Time taken for 1 epoch 197.97 sec
#
# Epoch 5 Batch 0 Loss 0.8462
# Epoch 5 Batch 100 Loss 0.9160
# Epoch 5 Batch 200 Loss 0.8191
# Epoch 5 Batch 300 Loss 0.9227
# Epoch 5 Loss 0.876376
# Time taken for 1 epoch 198.72 sec
#
# Epoch 6 Batch 0 Loss 0.8531
# Epoch 6 Batch 100 Loss 0.9016
# Epoch 6 Batch 200 Loss 0.7957
# Epoch 6 Batch 300 Loss 0.7481
# Epoch 6 Loss 0.822396
# Time taken for 1 epoch 199.25 sec
#
# Epoch 7 Batch 0 Loss 0.8247
# Epoch 7 Batch 100 Loss 0.8251
# Epoch 7 Batch 200 Loss 0.8304
# Epoch 7 Batch 300 Loss 0.7514
# Epoch 7 Loss 0.773887
# Time taken for 1 epoch 198.60 sec
#
# Epoch 8 Batch 0 Loss 0.7471
# Epoch 8 Batch 100 Loss 0.7549
# Epoch 8 Batch 200 Loss 0.6405
# Epoch 8 Batch 300 Loss 0.7632
# Epoch 8 Loss 0.729790
# Time taken for 1 epoch 197.16 sec
#
# Epoch 9 Batch 0 Loss 0.7217
# Epoch 9 Batch 100 Loss 0.7213
# Epoch 9 Batch 200 Loss 0.5806
# Epoch 9 Batch 300 Loss 0.6511
# Epoch 9 Loss 0.689226
# Time taken for 1 epoch 197.22 sec
#
# Epoch 10 Batch 0 Loss 0.7568
# Epoch 10 Batch 100 Loss 0.7174
# Epoch 10 Batch 200 Loss 0.6380
# Epoch 10 Batch 300 Loss 0.6465
# Epoch 10 Loss 0.652764
# Time taken for 1 epoch 198.12 sec
#
# Epoch 11 Batch 0 Loss 0.6112
# Epoch 11 Batch 100 Loss 0.6144
# Epoch 11 Batch 200 Loss 0.6218
# Epoch 11 Batch 300 Loss 0.5659
# Epoch 11 Loss 0.617240
# Time taken for 1 epoch 198.65 sec
#
# Epoch 12 Batch 0 Loss 0.6077
# Epoch 12 Batch 100 Loss 0.5282
# Epoch 12 Batch 200 Loss 0.6131
# Epoch 12 Batch 300 Loss 0.6832
# Epoch 12 Loss 0.585100
# Time taken for 1 epoch 197.99 sec
#
# Epoch 13 Batch 0 Loss 0.5752
# Epoch 13 Batch 100 Loss 0.5943
# Epoch 13 Batch 200 Loss 0.5818
# Epoch 13 Batch 300 Loss 0.5616
# Epoch 13 Loss 0.553943
# Time taken for 1 epoch 197.24 sec
#
# Epoch 14 Batch 0 Loss 0.6712
# Epoch 14 Batch 100 Loss 0.4999
# Epoch 14 Batch 200 Loss 0.5593
# Epoch 14 Batch 300 Loss 0.4972
# Epoch 14 Loss 0.526332
# Time taken for 1 epoch 197.28 sec
#
# Epoch 15 Batch 0 Loss 0.6238
# Epoch 15 Batch 100 Loss 0.5204
# Epoch 15 Batch 200 Loss 0.5037
# Epoch 15 Batch 300 Loss 0.4621
# Epoch 15 Loss 0.499469
# Time taken for 1 epoch 197.90 sec
#
# Epoch 16 Batch 0 Loss 0.4868
# Epoch 16 Batch 100 Loss 0.4932
# Epoch 16 Batch 200 Loss 0.5764
# Epoch 16 Batch 300 Loss 0.3981
# Epoch 16 Loss 0.475330
# Time taken for 1 epoch 198.41 sec
#
# Epoch 17 Batch 0 Loss 0.4903
# Epoch 17 Batch 100 Loss 0.4317
# Epoch 17 Batch 200 Loss 0.4617
# Epoch 17 Batch 300 Loss 0.4542
# Epoch 17 Loss 0.452548
# Time taken for 1 epoch 198.25 sec
#
# Epoch 18 Batch 0 Loss 0.4946
# Epoch 18 Batch 100 Loss 0.4945
# Epoch 18 Batch 200 Loss 0.4648
# Epoch 18 Batch 300 Loss 0.4349
# Epoch 18 Loss 0.431032
# Time taken for 1 epoch 197.43 sec
#
# Epoch 19 Batch 0 Loss 0.4126
# Epoch 19 Batch 100 Loss 0.4232
# Epoch 19 Batch 200 Loss 0.4542
# Epoch 19 Batch 300 Loss 0.4296
# Epoch 19 Loss 0.409971
# Time taken for 1 epoch 197.37 sec
#
# Epoch 20 Batch 0 Loss 0.4404
# Epoch 20 Batch 100 Loss 0.4064
# Epoch 20 Batch 200 Loss 0.4010
# Epoch 20 Batch 300 Loss 0.3782
# Epoch 20 Loss 0.391788
# Time taken for 1 epoch 198.08 sec
#
# Epoch 21 Batch 0 Loss 0.4384
# Epoch 21 Batch 100 Loss 0.4390
# Epoch 21 Batch 200 Loss 0.4210
# Epoch 21 Batch 300 Loss 0.4058
# Epoch 21 Loss 0.375011
# Time taken for 1 epoch 198.58 sec
#
# Epoch 22 Batch 0 Loss 0.3706
# Epoch 22 Batch 100 Loss 0.3681
# Epoch 22 Batch 200 Loss 0.3184
# Epoch 22 Batch 300 Loss 0.3818
# Epoch 22 Loss 0.359420
# Time taken for 1 epoch 198.35 sec
#
# Epoch 23 Batch 0 Loss 0.4252
# Epoch 23 Batch 100 Loss 0.3489
# Epoch 23 Batch 200 Loss 0.3320
# Epoch 23 Batch 300 Loss 0.3433
# Epoch 23 Loss 0.343841
# Time taken for 1 epoch 197.27 sec
#
# Epoch 24 Batch 0 Loss 0.3655
# Epoch 24 Batch 100 Loss 0.3369
# Epoch 24 Batch 200 Loss 0.3326
# Epoch 24 Batch 300 Loss 0.3167
# Epoch 24 Loss 0.329954
# Time taken for 1 epoch 197.30 sec
#
# Epoch 25 Batch 0 Loss 0.3649
# Epoch 25 Batch 100 Loss 0.3129
# Epoch 25 Batch 200 Loss 0.3218
# Epoch 25 Batch 300 Loss 0.3140
# Epoch 25 Loss 0.316608
# Time taken for 1 epoch 197.95 sec
#
# Epoch 26 Batch 0 Loss 0.3458
# Epoch 26 Batch 100 Loss 0.3041
# Epoch 26 Batch 200 Loss 0.2911
# Epoch 26 Batch 300 Loss 0.3198
# Epoch 26 Loss 0.306077
# Time taken for 1 epoch 198.81 sec
#
# Epoch 27 Batch 0 Loss 0.4076
# Epoch 27 Batch 100 Loss 0.2810
# Epoch 27 Batch 200 Loss 0.2459
# Epoch 27 Batch 300 Loss 0.3229
# Epoch 27 Loss 0.294330
# Time taken for 1 epoch 198.40 sec
#
# Epoch 28 Batch 0 Loss 0.2950
# Epoch 28 Batch 100 Loss 0.2891
# Epoch 28 Batch 200 Loss 0.2877
# Epoch 28 Batch 300 Loss 0.3116
# Epoch 28 Loss 0.283831
# Time taken for 1 epoch 197.20 sec
#
# Epoch 29 Batch 0 Loss 0.3587
# Epoch 29 Batch 100 Loss 0.3002
# Epoch 29 Batch 200 Loss 0.3140
# Epoch 29 Batch 300 Loss 0.2607
# Epoch 29 Loss 0.275137
# Time taken for 1 epoch 197.36 sec
#
# Epoch 30 Batch 0 Loss 0.3352
# Epoch 30 Batch 100 Loss 0.2735
# Epoch 30 Batch 200 Loss 0.2846
# Epoch 30 Batch 300 Loss 0.2567
# Epoch 30 Loss 0.265276
# Time taken for 1 epoch 197.91 sec
#
# Epoch 31 Batch 0 Loss 0.3135
# Epoch 31 Batch 100 Loss 0.2681
# Epoch 31 Batch 200 Loss 0.2492
# Epoch 31 Batch 300 Loss 0.2534
# Epoch 31 Loss 0.256165
# Time taken for 1 epoch 198.73 sec
#
# Epoch 32 Batch 0 Loss 0.2864
# Epoch 32 Batch 100 Loss 0.2704
# Epoch 32 Batch 200 Loss 0.2592
# Epoch 32 Batch 300 Loss 0.2840
# Epoch 32 Loss 0.249865
# Time taken for 1 epoch 198.36 sec
#
# Epoch 33 Batch 0 Loss 0.3291
# Epoch 33 Batch 100 Loss 0.2476
# Epoch 33 Batch 200 Loss 0.2402
# Epoch 33 Batch 300 Loss 0.2282
# Epoch 33 Loss 0.242771
# Time taken for 1 epoch 197.51 sec
#
# Epoch 34 Batch 0 Loss 0.3314
# Epoch 34 Batch 100 Loss 0.2392
# Epoch 34 Batch 200 Loss 0.2479
# Epoch 34 Batch 300 Loss 0.2354
# Epoch 34 Loss 0.235423
# Time taken for 1 epoch 197.50 sec
#
# Epoch 35 Batch 0 Loss 0.2571
# Epoch 35 Batch 100 Loss 0.2263
# Epoch 35 Batch 200 Loss 0.2633
# Epoch 35 Batch 300 Loss 0.2272
# Epoch 35 Loss 0.229962
# Time taken for 1 epoch 198.00 sec
#
# Epoch 36 Batch 0 Loss 0.2694
# Epoch 36 Batch 100 Loss 0.2276
# Epoch 36 Batch 200 Loss 0.2021
# Epoch 36 Batch 300 Loss 0.2378
# Epoch 36 Loss 0.224349
# Time taken for 1 epoch 198.59 sec
#
# Epoch 37 Batch 0 Loss 0.2825
# Epoch 37 Batch 100 Loss 0.2287
# Epoch 37 Batch 200 Loss 0.2262
# Epoch 37 Batch 300 Loss 0.2256
# Epoch 37 Loss 0.218052
# Time taken for 1 epoch 198.30 sec
#
# Epoch 38 Batch 0 Loss 0.2495
# Epoch 38 Batch 100 Loss 0.2450
# Epoch 38 Batch 200 Loss 0.1875
# Epoch 38 Batch 300 Loss 0.2528
# Epoch 38 Loss 0.213836
# Time taken for 1 epoch 197.30 sec
#
# Epoch 39 Batch 0 Loss 0.2299
# Epoch 39 Batch 100 Loss 0.1955
# Epoch 39 Batch 200 Loss 0.2117
# Epoch 39 Batch 300 Loss 0.2241
# Epoch 39 Loss 0.208961
# Time taken for 1 epoch 197.52 sec
#
# Epoch 40 Batch 0 Loss 0.2726
# Epoch 40 Batch 100 Loss 0.2018
# Epoch 40 Batch 200 Loss 0.2023
# Epoch 40 Batch 300 Loss 0.2106
# Epoch 40 Loss 0.204583
# Time taken for 1 epoch 198.05 sec
#
# Epoch 41 Batch 0 Loss 0.2466
# Epoch 41 Batch 100 Loss 0.1785
# Epoch 41 Batch 200 Loss 0.1951
# Epoch 41 Batch 300 Loss 0.1875
# Epoch 41 Loss 0.200447
# Time taken for 1 epoch 198.56 sec
#
# Epoch 42 Batch 0 Loss 0.2184
# Epoch 42 Batch 100 Loss 0.1890
# Epoch 42 Batch 200 Loss 0.1733
# Epoch 42 Batch 300 Loss 0.1834
# Epoch 42 Loss 0.197366
# Time taken for 1 epoch 198.40 sec
#
# Epoch 43 Batch 0 Loss 0.2314
# Epoch 43 Batch 100 Loss 0.1785
# Epoch 43 Batch 200 Loss 0.2016
# Epoch 43 Batch 300 Loss 0.2319
# Epoch 43 Loss 0.194451
# Time taken for 1 epoch 197.56 sec
#
# Epoch 44 Batch 0 Loss 0.2358
# Epoch 44 Batch 100 Loss 0.1761
# Epoch 44 Batch 200 Loss 0.2007
# Epoch 44 Batch 300 Loss 0.1969
# Epoch 44 Loss 0.192014
# Time taken for 1 epoch 197.60 sec
#
# Epoch 45 Batch 0 Loss 0.2431
# Epoch 45 Batch 100 Loss 0.1945
# Epoch 45 Batch 200 Loss 0.1798
# Epoch 45 Batch 300 Loss 0.1680
# Epoch 45 Loss 0.187992
# Time taken for 1 epoch 198.58 sec
#
# Epoch 46 Batch 0 Loss 0.2096
# Epoch 46 Batch 100 Loss 0.2089
# Epoch 46 Batch 200 Loss 0.1975
# Epoch 46 Batch 300 Loss 0.1757
# Epoch 46 Loss 0.184734
# Time taken for 1 epoch 198.87 sec
#
# Epoch 47 Batch 0 Loss 0.2350
# Epoch 47 Batch 100 Loss 0.1977
# Epoch 47 Batch 200 Loss 0.1789
# Epoch 47 Batch 300 Loss 0.1894
# Epoch 47 Loss 0.182524
# Time taken for 1 epoch 198.51 sec
#
# Epoch 48 Batch 0 Loss 0.2010
# Epoch 48 Batch 100 Loss 0.1722
# Epoch 48 Batch 200 Loss 0.1791
# Epoch 48 Batch 300 Loss 0.1778
# Epoch 48 Loss 0.178252
# Time taken for 1 epoch 197.37 sec
#
# Epoch 49 Batch 0 Loss 0.1911
# Epoch 49 Batch 100 Loss 0.1948
# Epoch 49 Batch 200 Loss 0.1910
# Epoch 49 Batch 300 Loss 0.2143
# Epoch 49 Loss 0.176978
# Time taken for 1 epoch 197.26 sec
#
# Epoch 50 Batch 0 Loss 0.1997
# Epoch 50 Batch 100 Loss 0.1730
# Epoch 50 Batch 200 Loss 0.2016
# Epoch 50 Batch 300 Loss 0.1763
# Epoch 50 Loss 0.175731
# Time taken for 1 epoch 198.24 sec
#
# Epoch 51 Batch 0 Loss 0.2129
# Epoch 51 Batch 100 Loss 0.1693
# Epoch 51 Batch 200 Loss 0.1673
# Epoch 51 Batch 300 Loss 0.1869
# Epoch 51 Loss 0.173014
# Time taken for 1 epoch 198.62 sec
#
# Epoch 52 Batch 0 Loss 0.2400
# Epoch 52 Batch 100 Loss 0.1782
# Epoch 52 Batch 200 Loss 0.1818
# Epoch 52 Batch 300 Loss 0.1759
# Epoch 52 Loss 0.172091
# Time taken for 1 epoch 198.54 sec
#
# Epoch 53 Batch 0 Loss 0.2060
# Epoch 53 Batch 100 Loss 0.1725
# Epoch 53 Batch 200 Loss 0.1726
# Epoch 53 Batch 300 Loss 0.1576
# Epoch 53 Loss 0.167939
# Time taken for 1 epoch 197.49 sec
#
# Epoch 54 Batch 0 Loss 0.2061
# Epoch 54 Batch 100 Loss 0.1684
# Epoch 54 Batch 200 Loss 0.1982
# Epoch 54 Batch 300 Loss 0.1810
# Epoch 54 Loss 0.166769
# Time taken for 1 epoch 197.69 sec
#
# Epoch 55 Batch 0 Loss 0.2273
# Epoch 55 Batch 100 Loss 0.1904
# Epoch 55 Batch 200 Loss 0.1603
# Epoch 55 Batch 300 Loss 0.1706
# Epoch 55 Loss 0.166068
# Time taken for 1 epoch 198.40 sec
#
# Epoch 56 Batch 0 Loss 0.2028
# Epoch 56 Batch 100 Loss 0.1550
# Epoch 56 Batch 200 Loss 0.1560
# Epoch 56 Batch 300 Loss 0.1923
# Epoch 56 Loss 0.163824
# Time taken for 1 epoch 198.45 sec
#
# Epoch 57 Batch 0 Loss 0.1948
# Epoch 57 Batch 100 Loss 0.1597
# Epoch 57 Batch 200 Loss 0.1563
# Epoch 57 Batch 300 Loss 0.1620
# Epoch 57 Loss 0.162059
# Time taken for 1 epoch 198.32 sec
#
# Epoch 58 Batch 0 Loss 0.1924
# Epoch 58 Batch 100 Loss 0.1657
# Epoch 58 Batch 200 Loss 0.1659
# Epoch 58 Batch 300 Loss 0.1655
# Epoch 58 Loss 0.162601
# Time taken for 1 epoch 197.46 sec
#
# Epoch 59 Batch 0 Loss 0.1753
# Epoch 59 Batch 100 Loss 0.1824
# Epoch 59 Batch 200 Loss 0.1640
# Epoch 59 Batch 300 Loss 0.1577
# Epoch 59 Loss 0.159808
# Time taken for 1 epoch 197.60 sec
#
# Epoch 60 Batch 0 Loss 0.1741
# Epoch 60 Batch 100 Loss 0.1493
# Epoch 60 Batch 200 Loss 0.1514
# Epoch 60 Batch 300 Loss 0.1685
# Epoch 60 Loss 0.158022
# Time taken for 1 epoch 198.01 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Caption

# %%
def evaluate_categorical(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)
    if (CNN_USED == 'InceptionV3'):
      temp_input = tf.expand_dims(load_image_InceptionV3(image)[0], 0)
    else:
      temp_input = tf.expand_dims(load_image_ResNet152v2(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)
        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()
        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        predicted_word = tf.compat.as_text(index_to_word(predicted_id).numpy())
        result.append(predicted_word)

        if predicted_word == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def evaluate_beamSearch(image, beam_index = BEAM_WIDTH):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    if (CNN_USED == 'InceptionV3'):
      temp_input = tf.expand_dims(load_image_InceptionV3(image)[0], 0)
    else:
      temp_input = tf.expand_dims(load_image_ResNet152v2(image)[0], 0)
    
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([word_to_index('<start>')], 0)
    result = []
    
    start = [word_to_index("<start>")]
    
    predicted_ids = [[start, 0.0]]
    
    for i in range(max_length):
        temp=[]
        for s in predicted_ids:
            dec_input = tf.expand_dims([s[0][-1]], 0)
            predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)
        
            attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

            predictions = tf.nn.softmax(predictions)
        
            word_preds = np.argsort(predictions[0])[-beam_index:]
            for w in word_preds:
                    next_cap, prob = s[0][:], s[1]
                    next_cap.append(w)
                    prob += predictions[0][w]
                    temp.append([next_cap, prob])
             
            
        predicted_ids = temp
        predicted_ids = sorted(predicted_ids, reverse=False, key=lambda l: l[1])
        
        predicted_ids = predicted_ids[-beam_index:]
        if tf.compat.as_text(index_to_word(predicted_ids[0][0][-1]).numpy()) == '<end>' and tf.compat.as_text(index_to_word(predicted_ids[1][0][-1]).numpy()) == '<end>' and tf.compat.as_text(index_to_word(predicted_ids[2][0][-1]).numpy()) == '<end>':
            break
        
        
        
    pred_id = predicted_ids[-1][0]
    for j in pred_id[1:]:
        pred_word = tf.compat.as_text(index_to_word(j).numpy())
        if pred_word != '<end>':
            result.append(pred_word)
        else:
            break

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def evaluate(image):
  if SENTENCE_GENERATOR_METHOD == 'CATEGORICAL':
    return evaluate_categorical(image)
  else:
    return evaluate_beamSearch(image)

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(int(np.ceil(len_result/2)), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
# rid = np.random.randint(0, len(img_name_val))
rid = 99
image = img_name_val[rid]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                         for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a man and two young children are fishing by a pond . <end>
# Prediction Caption: a group of people setting across the water . <end>

# %%
index = 99
image = img_name_val[index]
real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                        for i in cap_val[index] if i not in [0]])
result, attention_plot = evaluate(image)
print('Real Caption:', real_caption[8:-5])
print('Prediction Caption:', ' '.join(result[:-1]))
Image.open(image)
# Out:
# Real Caption: a man and two young children are fishing by a pond .
# Prediction Caption: a group of people near a large body of water .
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=478x500 at 0x7F055E22E250>

# %% [markdown]
# ## Αξιολόγηση της ποιότητας του captioning χρησιμοποιώντας τη μετρική BLEU

# %%
weights = (0.4, 0.3, 0.2, 0.1)
smoothing_function = SmoothingFunction().method1

def sentence_bleu_calc(references,hyp):
  return(nltk.translate.bleu_score.sentence_bleu(
                                          references, 
                                          hyp, 
                                          weights = weights, 
                                          smoothing_function=smoothing_function))

def corpus_bleu_calc(list_of_references, list_of_hypotheses):
  return(nltk.translate.bleu_score.corpus_bleu(list_of_references, 
                                               list_of_hypotheses, 
                                               weights = weights, 
                                               smoothing_function=smoothing_function))

# %%
list_of_references = []
list_of_hypotheses = []
sentence_bleu_values = []

real_captions = []
last_img = img_name_val[0]

for index in tqdm(range(0,len(img_name_val))):
  image = img_name_val[index]
  real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy())
                      for i in cap_val[index] if i not in [0]])
  if (image == last_img):
    real_captions.append(real_caption.split()[1:-1])
  else:
    result, attention_plot = evaluate(last_img)
    sentence_bleu_values.append(sentence_bleu_calc(real_captions,result[:-1]))
    list_of_references.append(real_captions)
    list_of_hypotheses.append(result[:-1])

    real_captions = []
    real_captions.append(real_caption.split()[1:-1])
    last_img = image


corpus_bleu_value = corpus_bleu_calc(list_of_references,list_of_hypotheses)
# Out:
# 100%|██████████| 5993/5993 [39:16<00:00,  2.54it/s]

# %%
n, bins, patches = plt.hist(sentence_bleu_values, bins=len(sentence_bleu_values))

plt.xlabel('Value of sentence_bleu()')
plt.ylabel('Number of captions')
plt.title('Histogram of sentence_bleu() values')

plt.grid(True)
plt.show()

# %%
print('Corpus Bleu Value:',corpus_bleu_value)
# Out:
# Corpus Bleu Value: 0.11628245379724368
